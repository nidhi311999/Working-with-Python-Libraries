# %% [markdown]
# ## Introduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
fig = plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
fig =plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250]);
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[11,22,33,44]
fig,ax=plt.subplots(figsize=(10,10))
ax.plot(x,y)
ax.set(title="Simple Plot",xlabel="x-axis",ylabel="y-axis")
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## making figure with numpy arrays

# %%
import numpy as np

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %%
nut_butter_prices={"Almond butter":10,
                   "Peanut butter":8,
                   "Cashew butter":12
                  }
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Butter Store",ylabel="Price($)");

# %%
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x=np.random.randn(1000)
fig,ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas dataframe

# %%
import pandas as pd

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
   ...:                index=pd.date_range('1/1/2000', periods=1000))
   ...: 

In [4]: ts = ts.cumsum()

In [5]: ts.plot()
Out[5]: <matplotlib.axes._subplots.AxesSubplot at 0x7f3d08e14790>

# %%
ts = pd.Series(np.random.randn(1000),
                index=pd.date_range("20/5/2020",periods=1000))
ts=ts.cumsum()
ts.plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("20/5/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-05-20
# 1   Honda    Red          87899      4   5000 2020-05-21
# 2  Toyota   Blue          32549      3   7000 2020-05-22
# 3     BMW  Black          11179      5  22000 2020-05-23
# 4  Nissan  White         213095      4   3500 2020-05-24
# 5  Toyota  Green          99213      4   4500 2020-05-25
# 6   Honda   Blue          45698      4   7500 2020-05-26
# 7   Honda   Blue          54738      4   7000 2020-05-27
# 8  Toyota  White          60000      4   6250 2020-05-28
# 9  Nissan  White          31600      4   9700 2020-05-29

# %%
car_sales["Total sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2020-05-20         4000
# 1   Honda    Red          87899      4   5000 2020-05-21         9000
# 2  Toyota   Blue          32549      3   7000 2020-05-22        16000
# 3     BMW  Black          11179      5  22000 2020-05-23        38000
# 4  Nissan  White         213095      4   3500 2020-05-24        41500
# 5  Toyota  Green          99213      4   4500 2020-05-25        46000
# 6   Honda   Blue          45698      4   7500 2020-05-26        53500
# 7   Honda   Blue          54738      4   7000 2020-05-27        60500
# 8  Toyota  White          60000      4   6250 2020-05-28        66750
# 9  Nissan  White          31600      4   9700 2020-05-29        76450

# %%
car_sales["Price"][0]
# Out:
# '4000'

# %%
car_sales.plot(x="Sale Date",y="Total sales");

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2020-05-20         4000
# 1   Honda    Red          87899      4   5000 2020-05-21         9000
# 2  Toyota   Blue          32549      3   7000 2020-05-22        16000
# 3     BMW  Black          11179      5  22000 2020-05-23        38000
# 4  Nissan  White         213095      4   3500 2020-05-24        41500
# 5  Toyota  Green          99213      4   4500 2020-05-25        46000
# 6   Honda   Blue          45698      4   7500 2020-05-26        53500
# 7   Honda   Blue          54738      4   7000 2020-05-27        60500
# 8  Toyota  White          60000      4   6250 2020-05-28        66750
# 9  Nissan  White          31600      4   9700 2020-05-29        76450

# %%
car_sales.plot(x="Sale Date",y="Total sales")

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="bar");

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="hist");

# %%
import numpy as np

# %%
x=np.random.rand(10,4)
x

df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.542649  0.604518  0.628962  0.757430
# 1  0.104489  0.178742  0.570308  0.903034
# 2  0.241499  0.053220  0.429365  0.981701
# 3  0.642001  0.318120  0.324740  0.427553
# 4  0.303196  0.205822  0.786204  0.508748
# 5  0.679378  0.896951  0.382862  0.264170
# 6  0.228979  0.363594  0.787303  0.519857
# 7  0.344921  0.501991  0.630985  0.816407
# 8  0.676721  0.940393  0.519950  0.575682
# 9  0.577817  0.292578  0.209221  0.726473

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0b82018841ae> in <module>
# ----> 1 car_sales
#
# NameError: name 'car_sales' is not defined

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2020-05-20         4000
# 1   Honda    Red          87899      4   5000 2020-05-21         9000
# 2  Toyota   Blue          32549      3   7000 2020-05-22        16000
# 3     BMW  Black          11179      5  22000 2020-05-23        38000
# 4  Nissan  White         213095      4   3500 2020-05-24        41500
# 5  Toyota  Green          99213      4   4500 2020-05-25        46000
# 6   Honda   Blue          45698      4   7500 2020-05-26        53500
# 7   Honda   Blue          54738      4   7000 2020-05-27        60500
# 8  Toyota  White          60000      4   6250 2020-05-28        66750
# 9  Nissan  White          31600      4   9700 2020-05-29        76450

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
heart_disease=pd.read_csv("heart-disease.csv")

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart_disease[heart_disease["age"]>50]
len(over_50)
# Out:
# 208

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind='scatter',x='age',y='chol',c='target');

# %%
fig,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',x='age',y='chol',c='target',ax=ax);
#ax.set_xlim([45,100])

# %%
fig,ax=plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax.set(title="Heart Disease and cholestrol level",xlabel="Age",ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(),title="Tartget");
ax.axhline(over_50["chol"].mean(),linestyle='--')

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6))=plt.subplots(nrows=2,ncols=3,figsize=(10,6))
ax1.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax1.set(title="Heart Disease and cholestrol level",xlabel="Age",ylabel="Cholestrol")
ax1.legend(*scatter.legend_elements(),title="Tartget");
ax1.axhline(over_50["chol"].mean(),linestyle='--')

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax0.set(title="Heart Disease and cholestrol level",ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),linestyle='--')

scatter=ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"])
ax1.set(title="Heart Disease and Max Heart rate",xlabel="Age",ylabel="Max heart rate")
ax1.legend(*scatter.legend_elements(),title="target")
ax1.axhline(y=over_50["thalach"].mean(),linestyle='--')
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## Customizing matplotlib

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2020-05-20         4000
# 1   Honda    Red          87899      4   5000 2020-05-21         9000
# 2  Toyota   Blue          32549      3   7000 2020-05-22        16000
# 3     BMW  Black          11179      5  22000 2020-05-23        38000
# 4  Nissan  White         213095      4   3500 2020-05-24        41500

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot()

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot();

# %%
x=np.random.randn(10,4)
x
# Out:
# array([[-0.10637316, -0.90993137, -0.59701796,  0.08328083],
#        [-0.27479584,  0.40401038,  1.50114619, -1.16216741],
#        [ 0.75275175,  1.51517565, -1.4558129 ,  2.61505052],
#        [ 0.45096903,  0.37352302, -0.4400056 ,  0.35963162],
#        [ 1.41584269,  0.54178692, -1.05201804, -0.80714482],
#        [-0.23909692, -0.27892674,  0.17935419,  0.81305306],
#        [-0.40333408, -0.51091664,  0.46251008, -0.09521909],
#        [ 0.02127543, -2.27393474,  0.87102305,  0.64702504],
#        [ 0.56627248, -2.23885819, -0.37630948, -1.72648425],
#        [ 0.27214557,  1.14675182,  0.44625434,  3.4289648 ]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.106373 -0.909931 -0.597018  0.083281
# 1 -0.274796  0.404010  1.501146 -1.162167
# 2  0.752752  1.515176 -1.455813  2.615051
# 3  0.450969  0.373523 -0.440006  0.359632
# 4  1.415843  0.541787 -1.052018 -0.807145
# 5 -0.239097 -0.278927  0.179354  0.813053
# 6 -0.403334 -0.510917  0.462510 -0.095219
# 7  0.021275 -2.273935  0.871023  0.647025
# 8  0.566272 -2.238858 -0.376309 -1.726484
# 9  0.272146  1.146752  0.446254  3.428965

# %%
ax=df.plot(kind="bar")

# %%
ax=df.plot(kind="bar")
ax.set(title="Random bar graph from dataframe",xlabel="Row number",ylabel="Random number")
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-whitegrid')
fig,ax=plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter")
ax.set(title="Heart Disease and cholestrol level",xlabel="Age",ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(),title="Tartget");
ax.axhline(over_50["chol"].mean(),linestyle='--')

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter")
ax0.set(title="Heart Disease and cholestrol level",ylabel="Cholestrol")
ax0.set_xlim([50,80])
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),linestyle='--')

scatter=ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"],cmap="winter")
ax1.set(title="Heart Disease and Max Heart rate",xlabel="Age",ylabel="Max heart rate")
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
ax1.legend(*scatter.legend_elements(),title="target")
ax1.axhline(y=over_50["thalach"].mean(),linestyle='--')
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')
